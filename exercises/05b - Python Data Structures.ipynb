# %% [markdown]
# # 05b - Python Data Structures

# %% [markdown]
# ## Esercizio 1 - visited_countries
# Definisci una lista contenente i paesi che hai visitato dandole nome `visited_countries`.
# Dopodiché definisci una lista contenente i paesi che vorresti visitare dandole nome `countries_to_visit`.
# Infine unisci le due liste in una singola lista di paesi dandole nome `my_countries`.
# Stampa la lista a schermo.

# %%
visited_countries = [ 'Italy', 'Germania', 'UK', 'Emirati Arabi Uniti' ]
countries_to_visit = [ 'USA', 'Egypt' ]
my_countries = visited_countries + countries_to_visit
my_countries = []
my_countries.extend(visited_countries)

# %% [markdown]
# ## Esercizio 2 - club
#
# Definisci un set con nome `club`. Il set contiene il nome delle persone che fanno parte del club.
# Scrivi una funzione che consenta l'aggiunta al club dopo aver controllato che alla funzione sia passata una stringa.
# ```python
# def add_to_club(club, name)
# ```
# Scrivi una funzione che permetta di controllare se una persona fa parte del club. La funzione ritorna `True` se la persona fa parte del club, `False` altrimenti.
# ```python
# def check_person_in_club(club, name)

# %% [markdown]
# ## Esercizio 3 - transaction
# Definisci una funzione che permetta di aggiungere delle transazioni ad una lista.
# Una transazione è un dizionario con le seguenti chiavi:
# - `to`: indica la persona che riceverà la transazione
# - `subject`: è una descrizione della transazione
# - `amount`: indica l'ammontare della transazione
#
# La funzione di aggiunta di transazioni ha la seguente firma:
# ```python
# def add_transaction(transaction_list, to, subject, amount)
# ```

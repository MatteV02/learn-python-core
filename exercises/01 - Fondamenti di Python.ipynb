# %% [markdown]
# # 01 - Fondamenti di Python
# ## Esercizi
#
# Questi esercizi coprono i concetti di base introdotti nel notebook dei fondamenti di Python.
#
# ### Istruzioni
#
# Completa ogni esercizio nel modo migliore che puoi. Se ti blocchi chiedi aiuto al docente o ripassa il contenuto della lezione!

# %% [markdown]
# ## Esercizio 1: Storia di Python
# In che anno è stato rilasciato Python 3?
# **Riempi la variabile col valore esatto** (cerca pure su Google o sulle slides)

# %%
year_python3 = # Inserisci la tua risposta qui
print(f"Python 3 è stato rilasciato nel {year_python3}.")

# %% [markdown]
# ## Esercizio 2: Vantaggi di Python
# Cita tre vantaggi di Python dalle slide.
# **Riempi le stringhe**

# %%
advantages = [  # Inserisci la tua risposta qui
    "1. ",  
    "2. ",
    "3. "
]
for advantage in advantages:
    print(advantage)

# %% [markdown]
# ## Esercizio 3: Zen di Python
# **Riempi la variabile** con una stringa che spieghi uno dei principi dello Zen di Python.

# %%
zen_principle = # riempi la variabile qui
print(zen_principle)

# %% [markdown]
# ## Esercizio 4: Variabili e tipi di dati
# Crea una variabile per ogni tipo di dato (intero, float, stringa, booleano) e stampa il loro tipo.

# %%
int_var =  # Inserisci un intero qui
float_var =  # Inserisci un float qui
str_var =  # Inserisci una stringa qui
bool_var =  # Inserisci un booleano qui

print(f"Tipo di int_var: {type(int_var)}")
print(f"Tipo di float_var: {type(float_var)}")
print(f"Tipo di str_var: {type(str_var)}")
print(f"Tipo di bool_var: {type(bool_var)}")

# %% [markdown]
# ## Esercizio 4b: Assegnamento variabili e costanti
# Nel prossimo esercizio assegna ad una variabile un valore a piacere, poi dopo assegna a una costante un valore a piacere e stampa entrambe le variabili.

# %%
# definisci e riempi la prima variabile
# definisci e riempi la costante
print() # stampa la prima variabile
print() # stampa la costante

# %% [markdown]
# ## Esercizio 5: Docstring
# Scrivi una docstring che spiega cosa fa la funzione.

# %%
def greet(name):
    
    return f"Ciao, {name}!"

print(greet("Mondo"))

# %% [markdown]
# ## Esercizio 6: Operazioni numeriche
# Scrivi un programma che esegue alcune operazioni matematiche di base (addizione, sottrazione, moltiplicazione, divisione) e stampa i risultati.

# %%
a = 10
b = 4

addizione = # somma a e b
sottrazione = # ad a sottraiamo b
moltiplicazione = # moltiplica a con b
divisione = # dividi a per b
resto = # calcola il resto della divisione di a per b
potenza = # calcola a elevato alla b

print(f"Addizione: {addizione}")
print(f"Sottrazione: {sottrazione}")
print(f"Moltiplicazione: {moltiplicazione}")
print(f"Divisione: {divisione}")
print(f"Resto: {resto}")
print(f"Potenza: {potenza}")

# %% [markdown]
# ## Esercizio 6b
# Traduci questa espressione in Python:
# $$
# \frac{(7 + 2)^2}{3} - 5 \cdot 4 + 10
# $$

# %%
risultato = # scrivi qui l'espressione
print(f"Risultato: {risultato}")

# %% [markdown]
# ## Esercizio 7: Conversione di tipo
# Converte una stringa che rappresenta un numero in un intero e poi in un float.

# %%
num_str = "123"
num_int = # converti num_str in intero
num_float = # converti num_str in stringa
print(f"Stringa: {num_str}, Intero: {num_int}, Float: {num_float}")

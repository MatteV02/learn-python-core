# %% [markdown]
# # 07a - PyGame graphics
#
# ## Esercizio 1 - Disegna un rettangolo e un cerchio
# Replica la seguente schermata:
# <img src="resources/07a-es1.png" alt="schermata esercizio 1" width=350>

# %% [markdown]
# ## Esercizio 2 - Disegna una x
#
# Replica la seguente schermata:
# <img src="resources/07a-es2.png" alt="schermata esercizio 2" width=350>

# %% [markdown]
# ## Esercizio 3 - Disegna un rombo
# Replica la seguente schermata:
# <img src="resources/07a-es3.png" alt="schermata esercizio 3" width=350>

# %% [markdown]
# ## Esercizio 4 - Stampa una scritta a schermo
# Replica la seguente schermata:
# <img src="resources/07a-es4.png" alt="schermata esercizio 4" width=350>
# Puoi scaricare un font a piacere da internet. Sito consigliato: [FontSource](https://fontsource.org/).

# %% [markdown]
# ## Esercizio 5 - Stampa una foresta
# Replica la seguente schermata:
# <img src="resources/07a-es5.png" alt="schermata esercizio 5" width=350>
# Se non riesci a replicare l'intera griglia non ti preoccupare! Stampa almeno 3 alberi nella posizione che vuoi tu.
#
# Il sito consigliato per scaricare le icone è [Sprite Catalog](https://www.spritecatalog.com/).
